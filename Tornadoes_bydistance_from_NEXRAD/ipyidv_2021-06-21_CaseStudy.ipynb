# %% [markdown]
# # Naperville, IL tornado June 2021
#
# This notebook was created in a Jupyter environment with `ipyidv` (an "extension") installed. Running it in `jupyter lab` on a computer with both IDV and Jupyter installed allows the screen captures to work. To install ipyidv, use `pip install ipyidv`.
#
# #### "On June 20, 2021, an EF3 tornado went through Naperville, uprooting trees, injuring eight people, and damaging 231 homes" [Wikipedia page](https://wikipedia.org/en/).
#
# The NWS has a [web page](https://www.weather.gov/lot/2021jun2021) clarifying the timing: "During the late evening into early overnight of Sunday, June 20, storms increased in intensity rapidly as they moved toward and into the Chicago metropolitan area, with damaging winds and three tornadoes." A useful central time marker would therefore be **06 UTC on 21 June, 2021**. A surface pressure trough and cold cloud shield covered all of Illinois at that hour (first figure below).

# %%
reload_ext ipyidv
# Out:
# xarray package is missing, functionality related to loading datafrom xarray into IDV will not be available
# netCDF4 is not installed
# ...

# %%
# %make_image -capture legend -caption "Elongated SLP Low and IR cold cloud shield covers Illinois at 2021-06-21 06UTC"

# %% [markdown]
# # Synoptic context
#
# ### 500 hPa heights and vorticity
#
# A broad, stationary trough from Montana to New York carried a series of sub-state-sized short waves (cyclonic vorticity anomalies,in red) across the upper Midwest on 20-21 June, 2021.

# %%
# %make_movie -capture legend -caption "Broad trough with shortwaves"

# %% [markdown]
# ### Surface pressure and 10m winds
#
# At the surface, a Low closed and deepened suring the event (00-12 UTC)

# %%
# %make_movie -capture legend -caption "Surface Low closed and deepened during the event (00-12 UTC)"

# %%
# %make_image -capture legend -caption "Elongated SLP Low and IR cold cloud shield covers Illinois at 2021-06-21 06UTC"
